# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.10.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting defusedxml (from nltk)
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting click (from nltk)
#   Using cached click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting joblib (from nltk)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2026.7.19-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk)
#   Downloading tqdm-4.70.0-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in .\venv\Lib\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.10.2-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------ --------------- 1.0/1.7 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 4.3 MB/s  0:00:00
# Downloading regex-2026.7.19-cp311-cp311-win_amd64.whl (277 kB)
# Using cached click-8.4.2-py3-none-any.whl (119 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading tqdm-4.70.0-py3-none-any.whl (80 kB)
# Installing collected packages: tqdm, regex, joblib, defusedxml, click, nltk
#
#    ---------------------------------------- 0/6 [tqdm]
#    ---------------------------------------- 0/6 [tqdm]
#    ---------------------------------------- 0/6 [tqdm]
#    ------ --------------------------------- 1/6 [regex]
#    ------ --------------------------------- 1/6 [regex]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    -------------------- ------------------- 3/6 [defusedxml]
#    -------------------------- ------------- 4/6 [click]
#    -------------------------- ------------- 4/6 [click]
#    -------------------------- ------------- 4/6 [click]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    ---------------------------------------- 6/6 [nltk]
#
# Successfully installed click-8.4.2 defusedxml-0.7.1 joblib-1.5.3 nltk-3.10.2 regex-2026.7.19 tqdm-4.70.0

# %%
corpus = """Hello, world! This is Ananya Kumar.
Please practice coding regularly to improve your programming skills.
"""

# %%
print(corpus)
# Out:
# Hello, world! This is Ananya Kumar.
# Please practice coding regularly to improve your programming skills.

# %%
##  Tokenization
## Sentence-->paragraphs
from nltk.tokenize import sent_tokenize

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello, world!
# This is Ananya Kumar.
# Please practice coding regularly to improve your programming skills.

# %%
## Tokenization 
## Paragraph-->words
## sentence--->words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'world',
#  '!',
#  'This',
#  'is',
#  'Ananya',
#  'Kumar',
#  '.',
#  'Please',
#  'practice',
#  'coding',
#  'regularly',
#  'to',
#  'improve',
#  'your',
#  'programming',
#  'skills',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', ',', 'world', '!']
# ['This', 'is', 'Ananya', 'Kumar', '.']
# ['Please', 'practice', 'coding', 'regularly', 'to', 'improve', 'your', 'programming', 'skills', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'world',
#  '!',
#  'This',
#  'is',
#  'Ananya',
#  'Kumar',
#  '.',
#  'Please',
#  'practice',
#  'coding',
#  'regularly',
#  'to',
#  'improve',
#  'your',
#  'programming',
#  'skills',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'world',
#  '!',
#  'This',
#  'is',
#  'Ananya',
#  'Kumar.',
#  'Please',
#  'practice',
#  'coding',
#  'regularly',
#  'to',
#  'improve',
#  'your',
#  'programming',
#  'skills',
#  '.']
